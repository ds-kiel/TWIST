# %% [markdown]
# # Detection Comparison

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

model_pretrained = YOLO("add file path here")
model_TRAYonly = YOLO("add file path here")
model_TRAY_COCO = YOLO("add file path here")

# ========= night =============
#train_2023-12-08_22.13.04_849.jpg"
#train_2023-12-08_19.31.24_192.jpg"
#train_2023-12-08_22.13.03_315.jpg"
# ========= blurr =============


# ========= night and blurr =============
#train_2023-12-08_19.30.58_147.jpg"

# ========= small bboxes =============
#train_2023-12-09_09.33.05_290.jpg"
#train_2023-12-09_13.32.35_414.jpg"
#train_2023-12-09_11.31.48_129.jpg"
#train_2023-12-09_11.18.52_966.jpg"
#train_2023-12-09_09.33.05_290.jpg"

image = "add image file path"


results_pretrained = model_pretrained(image) # model pre-trained on COCO dataset
results_TRAYonly = model_TRAYonly(image) # model trained on TRAY dataset only
results_TRAY_COCO = model_TRAY_COCO(image) # model trained on TRAY and COCO dataset

# %%
img = results_pretrained[0].plot()

plt.figure(figsize=(4, 4))
img = img[:, :, ::-1]   # BGR → RGB
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
img = results_TRAYonly[0].plot()

plt.figure(figsize=(4, 4))
img = img[:, :, ::-1]   # BGR → RGB
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
img = results_TRAY_COCO[0].plot()

plt.figure(figsize=(4, 4))
img = img[:, :, ::-1]   # BGR → RGB
plt.imshow(img)
plt.axis("off")
plt.show()
